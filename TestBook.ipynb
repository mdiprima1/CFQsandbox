# %% [markdown]
# Test Notebook no1

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
np.random.seed(0)
x = np.random.rand(50)
y = np.random.rand(50)
colors = np.random.rand(50)
sizes = 1000 * np.random.rand(50)

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='viridis')
plt.colorbar()  # Add a colorbar

# Customize plot labels and title
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot Example')

# Show the plot
plt.show()

# %% [markdown]
# This is streamlit

# %%
import streamlit as st
import numpy as np
import matplotlib.pyplot as plt

# Streamlit app header
st.title('Interactive Sine Wave Plot')

# User input for frequency and amplitude
frequency = st.slider('Frequency', 1, 10, 1)
amplitude = st.slider('Amplitude', 1.0, 10.0, 1.0)

# Generate data
x = np.linspace(0, 2 * np.pi, 100)
y = amplitude * np.sin(frequency * x)

# Create and display the plot
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Sine Wave Plot')
st.pyplot(fig)
# Out:
# 2023-09-27 16:46:34.978
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/marcodiprima/PycharmProjects/CFQ sandbox/lib/python3.11/site-packages/ipykernel_launcher.py [ARGUMENTS]
# DeltaGenerator()
